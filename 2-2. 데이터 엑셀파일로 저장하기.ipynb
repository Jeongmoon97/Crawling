# %% [markdown]
# ## OpenPyXL 페키지로 엑셀파일 만들기
#
# OpenpyXL은 파이썬을 활용해 엑셀파일을 읽고 쓸 수 있는 파이썬 오픈소스 페키지입니다.
#
# ### 엑셀의 구조
# - Workbook  엑셀파일 전체 작업공간, 엑셀파일 자체
# - Worksheet : 엑셀파일에서 단일 작업공간, 하나의 큰 표
# - Cell : 엑셀에서 데이터가 저장되어있는 가장 작은 공간
#
# ### 엑셀 파일 만들기/저장하기
# 1. openpyxl을 가져옵니다.
# ```python
# import openpyxl
# ```
#
# 2. 워크북(엑셀파일)을 새로 만듭니다.
# ```python
# wb = openpyxl.Workbook()
# ```
#
# 3. 워크북(엑셀파일)을 원하는 이름으로 저장합니다.
# ```python
# wb.save('test.xlsx')
# ```
#
# ### 시트 선택하기/데이터 쓰기
# 1. 우선, 현재 활성화된 시트를 선택합니다.
# ```python
# sheet = wb.active
# ```
#
# 2. 데이터를 입력합니다.
#     - 셀을 직접 지정하여 데이터를 입력
# ```python
# sheet['A1'] = 'hello world'
# ```
#
#     - 가장 마지막 줄에 데이터를 입력
# ```python
# sheet.append(['손\n흥민','이청,용','기성..용'])
# ```
#
#     - m행 n열에 데이터를 입력
# ```python
# sheet.cell(row=4,column=5).value='어렵다'
# ```
#
# ### 참고 함수
# 1. 새로운 시트를 원하는 이름으로 만드는 함수
# ```python
# sheet = wb.create_sheet('시트이름')
# ```
#
# 2. 특정 시트를 선택하는 함수
# ```python
# wb['시트이름']
# ```
#
# 3. 시트의 이름을 바꾸는 함수
# ```python
# sheet.title = '시트이름'
# ```
#
# ### 예시
# ```python
# import openpyxl
# wb = openpyxl.Workbook()
# sheet1 = wb.active
# sheet1.title = '1st sheet'
# sheet2 = wb.create_sheet('2st sheet')
# for i in range(1, 10):
#     sheet1.cell(row=i,column=1).value=i
#     sheet2.cell(row=1,column=i).value=i
# wb.save('test.xlsx')
# ```

# %% [markdown]
# ## 단계
# 1. 워크북 만들고 헤더 추가하기
# 2. 파일에 데이터 입력하기
# 3. 워크북 저장하기

# %% [markdown]
# ### ex1. 네이버 tv

# %%
import requests
from bs4 import BeautifulSoup

# 준비단계. openpyxl 가져오기
import openpyxl
# 1단계
# 1-1. 새로운 워크북 만들기
wb = openpyxl.Workbook()
# 1-2. 현재 시트 선택
sheet = wb.active
# 1-3. 헤더 추가하기
sheet.append(['제목','채널명','조회수','좋아요수'])

raw = requests.get('http://tv.naver.com/r')
html = BeautifulSoup(raw.text, 'html.parser')

container = html.select('dl.cds_info')

for clip in container:
    title = clip.select_one('dt.title').text.strip()
    chn = clip.select_one('dd.chn').text.strip()
    hit = clip.select_one('span.hit').text.strip()
    like = clip.select_one('span.like').text.strip()
    # 2단계. 워크북에 데이터를 추가하기
    # append 함수는 리스트 형식으로 데이터를 넣어준다.
    sheet.append([title, chn, hit, like])
    
# cf. 다음에서도 데이터를 가져오고 싶다면!
sheet2 = wb.create_sheet('다음 Top100')
sheet2['b2'] = '나중에 긁어오기'

# 3단계. 데이터 수집결과를 저장하기
wb.save('naver_tv100.xlsx')

# %% [markdown]
# ### ex2. 네이버 news

# %%
import requests
from bs4 import BeautifulSoup
import openpyxl
wb = openpyxl.Workbook()
sheet = wb.active
sheet.append(['제목','언론사'])

keyword = input('검색어를 입력하세요: ')

for n in range(1, 100, 10):
    raw = requests.get("https://search.naver.com/search.naver?where=news&sm=tab_jum&query="+keyword+"&start="+str(n),
                   headers={'User-Agent' : 'Morzilla/5.0'})
    html = BeautifulSoup(raw.text, "html.parser")
    
    articles = html.select("ul.type01>li")
    
    for ar in articles:
        title = ar.select_one("a._sp_each_title").text.strip().replace(',','_')
        source = ar.select_one("span._sp_each_source").text.strip().replace(',','_')
        print(title, source)
        sheet.append([title, source])
        
wb.save('naver_news.xlsx')
# Out:
# 검색어를 입력하세요: 코로나
# [속보] 코로나 210명 늘었다…총 확진자 3736명_ 사망 18명 중앙일보언론사 선정
# 文대통령 "코로나 이겨내고 위축된 경제 되살릴 수 있어"[전문] 파이낸셜뉴스언론사 선정
# 여야 "코로나 추경 '2월국회' 처리"…당정_ 내일 추경 협의(종합) 뉴시스
# 신천지 "오늘 이만희 총회장 코로나 진단검사"(종합) 연합뉴스언론사 선정
# 청하 스태프 2명 코로나19 확진…청하는 '음성'[전문] 이데일리
# [속보] 코로나19 신규 환자 210명…확진자 3736명으로 늘어 한겨레언론사 선정
# 경북 경산서 생후 45일 아기 코로나19 확진…전국 최연소(종합) 연합뉴스언론사 선정
# 청하 측 "코로나 19 음성 판정_ 자가격리 진행 중"[공식] 스포츠서울
# [단독]이만희 신천지 총회장_ 코로나 19 검사 받는다 채널A언론사 선정
# 경북 경산서 생후 45일 아기 코로나19 확진판정 오마이뉴스언론사 선정
# [단독] 코로나 진단키트 만든 씨젠 "적자 각오_ 다른건 접었다" 중앙일보언론사 선정
# [속보] 우한 코로나 국내 확진자 210명 추가…총 3736명 조선일보언론사 선정
# 청하 스태프 2명 코로나19 확진…청하는 '음성'[전문] 이데일리
# 경북 경산서 생후 45일 아기 코로나19 확진…전국 최연소(종합) 연합뉴스언론사 선정
# [속보] 코로나19 국내 확진자 210명 증가…누적 3_736명 KBS언론사 선정
# 경북 경산서 생후 45일 아기 코로나19 확진판정 오마이뉴스언론사 선정
# 대통령 "3·1정신으로 코로나 이겨야…TK 외롭지 않아" 미디어오늘언론사 선정
# 코로나 해외여행 취소 '대란'…위약금 분쟁 3배로 MBC언론사 선정
# 현대시티몰 가든파이브점_ 코로나 19 확진자 방문에 임시 휴점 조선비즈언론사 선정
# 청하와 밀라노 동행 스태프 2명 코로나 확진…청하는 음성(종합) 연합뉴스
# [단독] 황치열_ 코로나19 성금 5천만원 기부…따뜻한 선행 엑스포츠뉴스
# "코로나19 증상별 환자 분류·치료 필요…경증은 시설 격리치료"(종합) 연합뉴스
# 코로나 여파 對 중국 수출 6% 감소…2월 수출 15개월만에 플러스 조선일보언론사 선정
# 경북서 생후 45일 아기 코로나19 확진…전국 최연소 동아일보언론사 선정
# 코로나19 하루 신규확진 586명…총 3천736명·대구경북 3천260명(종합) 연합뉴스
# '코로나19 급증' 천안서 10대 확진자 속출…2차 감염 본격 시작(종합) 연합뉴스언론사 선정
# 코로나19 중증 이상 환자 증가세…중증 13명·위중 14명(종합) 뉴시스
# 코로나19 탓 '최소화'한 3·1절 기념식…훈장수여도 생략(종합) 연합뉴스
# 코로나 극복 메시지 '전진 배치'…정세 언급 줄어든 3·1절 기념사 뉴시스언론사 선정
# 문 대통령 "3·1 단결의 큰 힘 되새겨 코로나19 극복" 오마이뉴스언론사 선정
# [단독] '하바마' 스태프_ 코로나19 검사➝촬영 취소➝"2일 결과 나온다"(전문... OSEN
# 생후 45일 남아 코로나 최연소 확진···신천지 아빠에 감염 중앙일보언론사 선정
# "국내 코로나19 18번째 사망자 발생…83세 대구 남성" SBS언론사 선정
# 삼성·LG 구미사업장 코로나19 확진자 발생…주말 임시폐쇄 한겨레언론사 선정
# 여야 원내대표 3·1절 회동…코로나19 추경 논의 TV조선언론사 선정
# 문 대통령 "국가적 위기 때마다 3·1정신…코로나19 반드시 극복" MBC언론사 선정
# 범투본_ 광화문 대신 교회 집결…코로나 확산 우려 여전 뉴시스언론사 선정
# 신천지 신도_ 지난 1월 우한 방문…'코로나 허브' 원인 밝혀지나(종합) 아시아경제언론사 선정
# 코로나19 핑계로 직원 자르고 월급깎고…악성갑질 속출 뉴시스언론사 선정
# [속보]오늘 5시 기준 코로나 19 환자 3736명…사망 18명 채널A언론사 선정
# “코로나19 함께 극복하자”…인천시민 온정의 손길 이어져 한겨레언론사 선정
# [단독] 김태희 '하바마'_ 스태프A 코로나 의심→검사·자가격리..오늘(1일) 촬... OSEN
# "상생으로 코로나19 극복"…대구·경북서 임대료 감면 확산(종합) 연합뉴스
# [단독] 펭수_ 영상으로 코로나19 의료진 위로·응원 스포츠동아
# 코로나 타격에 상장사 1분기 영업익 작년比 -4% 전망 SBS CNBC언론사 선정
# "코로나19_ 겨울마다 오는 계절 전염병 될 가능성" YTN언론사 선정
# 검찰_ “우한 다녀왔는데 코로나19 의심” 허위신고 첫 구속기소 한겨레언론사 선정
# 국내 코로나19 18번째 사망자 발생…83세 대구 남성(종합) 연합뉴스언론사 선정
# 15개월 만에 반등에도 코로나19로 웃지 못한 한국 수출 연합뉴스언론사 선정
# "코로나19 이겨내자" 전국에서 성금 530억원 모였다 경향신문언론사 선정
# 국회_ 내일부터 대정부질문…코로나19 대응·추경 규모 공방(종합) 연합뉴스
# [코로나19] 과기정통부 "ICT R&D 기업부담 줄인다" 아이뉴스24언론사 선정
# 정세균 "코로나19 확산세 너무 빨라 병실 부족_ 특단의 대책 필요" 파이낸셜뉴스언론사 선정
# 신천지 "이만희_ 오늘 코로나19 진단검사…범죄 집단화 시도 멈춰달라"(종합) 아시아경제언론사 선정
# [속보] 코로나19 국내 확진자 210명 추가…총 3736명 국민일보
# 코로나19 피해 中企 기술료 납부 연장…R&D 민간부담금↓ ZDNet Korea언론사 선정
# 제네바모터쇼 취소…코로나 확산에 車산업 전방위 타격 조선비즈언론사 선정
# 한은 "코로나 여파_ 국제유가 한 달 만에 10%대 급락" 조선비즈언론사 선정
# [코로나19]미국_ 대구 '여행 금지' 경보 아이뉴스24언론사 선정
# 용인 기흥서 코로나19 확진자 1명 추가 발생(종합) 뉴시스
# [코로나19]우리금융_ 대구·경북지역 취약계층에 3억원 상당 생필품 지원 아이뉴스24언론사 선정
# [단독] 신한은행_ '코로나19' 대구‧경북 48개 全 영업점 단축근무 파이낸셜뉴스언론사 선정
# 코로나 376명 추가_ 총 3526명···대구·경북서만 359명 쏟아졌다 중앙일보언론사 선정
# 직원 코로나19 확진에 영덕보건소 폐쇄…진료 공백 우려(종합) 연합뉴스
# 코로나19 확산에 세계경제도 충격…"금융위기후 최저" 전망도 MBC언론사 선정
# 코로나19 확진 376명↑_ 총 3천526명…대구·경북 3천 명 넘어 SBS언론사 선정
# '코로나19' 확진자 1일 하루 586명 늘어…총 3736명(상보) 이데일리
# 천안·아산서 코로나19 확진 추가 발생…“충남 신천지 148명 유증상” 경향신문언론사 선정
# 지하철에서 '코로나19' 환자인척 장난을 친다면? 파이낸셜뉴스언론사 선정
# 고양 45세 남성 코로나19 확진…"대구동산병원 환자와 접촉"(종합) 연합뉴스
# 경남 '우한코로나' 확진자 신천지 女교인 1명 등 2명 추가발생 조선일보언론사 선정
# 문 대통령 "코로나19_ 단합과 희망 꺾을 수는 없어" YTN언론사 선정
# 충남 천안서 코로나19 12명 추가 확진…2세 아이도 포함 경향신문언론사 선정
# 코로나19 확진 376명 추가…모두 3_526명 MBC언론사 선정
# WHO "코로나19 양성 반응 나온 홍콩 애완견 조사 중" SBS언론사 선정
# "대구 333명 등 코로나19 추가 확진자 376명... 모두 3_526명" YTN언론사 선정
# 문 대통령 삼일절 기념식 축사…"코로나19 이겨낼 것" 노컷뉴스언론사 선정
# 코로나19 확산에 세계 경제도 충격…"금융위기 후 최저" 전망도 SBS언론사 선정
# 호주·태국서도 코로나19 첫 사망자 발생 연합뉴스TV언론사 선정
# 부산 코로나19 확진자 76명 중 이단 신천지 관련자 5명(종합) 노컷뉴스
# [속보] 코로나19 국내 확진자 210명 추가…총 3천736명 SBS언론사 선정
# 코로나19 확진자_ 밤새 376명 늘어…총 3526명 동아일보언론사 선정
# “재소자 ‘코로나19’ 첫 확진…교도소 확산 비상” KBS언론사 선정
# 삼성전자 이어 LG디스플레이 구미사업장도 ‘우한코로나’ 확진자 발생 조선일보언론사 선정
# 코로나19 확진 376명 추가_ 총 3526명…대구·경북 3000명 넘어 문화일보언론사 선정
# '코로나19' 국내 발생 40일 만에 확진자 3150명 경향신문언론사 선정
# 코로나19_ 마스크 구입 대란 뉴시스
# 신천지 신도 1월에도…'코로나 천지' 우한 다녀왔다 노컷뉴스언론사 선정
# 코로나19 밤새 594명 추가…총 2천931명·사망 16명 SBS언론사 선정
# 주유소 휘발유 가격 5주 연속 하락…'코로나' 영향 조선비즈언론사 선정
# 한국 수출 '코로나19' 악재 가시화되나 경향신문
# "생후 45일인데" 신생아_ 코로나19 확진 판정…아빠가 '신천지' 더팩트언론사 선정
# 코로나19에 3·1절 기념식 대폭 축소 MBC언론사 선정
# 文대통령 “안으로는 코로나19 극복_ 밖으로는 한반도 평화 이룰 것” 동아일보언론사 선정
# '코로나19'로 식습관도 변했다…즉석밥·구이팬 매출↑ 아시아경제언론사 선정
# 소규모 3·1절 기념식…"단합 정신으로 코로나19 극복" SBS언론사 선정
# 코로나19 확진자 376명 추가…총 3_526명 KBS언론사 선정
# '코로나19 사투의 흔적' 뉴시스
# 유통업계 코로나19 예방 위해 중소협력사 방역 지원 나서 경향신문
# WHO "코로나19 위험도 '매우 높음'…팬데믹 상황은 아직" SBS언론사 선정

# %% [markdown]
# ### ex2. 네이버 ebook

# %%
import requests
from bs4 import BeautifulSoup
import openpyxl
wb = openpyxl.Workbook()
sheet = wb.active
sheet.append(['제목','저자'])

for i in range(1,6):
    raw= requests.get("https://series.naver.com/ebook/top100List.nhn?page="+str(i),
                 headers = {'User-Agent': 'Morzilla/5.0'})
    html = BeautifulSoup(raw.text,'html.parser')

    container = html.select("ul.lst_thum.v1>li")

    for cont in container:
        title = cont.select_one("a strong").text.strip()
        author = cont.select_one("span.writer").text.strip()
        sheet.append([title, author])

wb.save('naver_ebook.xlsx')

# %% [markdown]
# ### 기존 파일 불러오기
#
# - load_workbook()을 활용하면 새로운 파일을 만들지 않고 기존에 저장한 엑셀파일을 가져와서 데이터를 추가할 수 있습니다.
#
# ```python
# wb = openpyxl.Workbook()
# ```
#
# ```python
# wb = openpyxl.load_workbook('naver_news.xlsx')
# ```
#
# - 이 때 불러올 파일이 없다면 에러를 발생시킵니다. 따라서 파일이 없는 경우에는 새로운 엑셀파일을 만들고, 파일이 있는 경우에는 기존 엑셀파일을 불러와서 데이터를 수집할 수 있습니다.
#
# ```python
# try:
#     실행문1
# except:
#     실행문2
# ```

# %%
import requests
from bs4 import BeautifulSoup
import openpyxl

# 1단계. 파일 불러오기를 시도합니다.
try:
    # 워크북 불러오기, 현재 활성화된 시트 선택하기
    wb = openpyxl.load_workbook('naver_keyword_news.xlsx')
    sheet = wb.active
    print('불러오기 완료')

# 2단계. 파일 불러오기에 실패하면, 새로운 워크북(엑셀파일)을 만듭니다.
except:
    # 워크북 새로 만들기, 현재 활성화된 시트 선택하기
    wb = openpyxl.Workbook()
    sheet = wb.active
    # 헤더 행 추가하기. 이 때, 검색여 열도 추가
    sheet.append(['검색어', '제목', '신문사'])
    print('새로운 파일을 만들었습니다.')

keyword = input('검색어를 입력하세요: ')

for n in range(1, 100, 10):
    raw = requests.get("https://search.naver.com/search.naver?where=news&sm=tab_jum&query="+keyword+"&start="+str(n),
                   headers={'User-Agent' : 'Morzilla/5.0'})
    html = BeautifulSoup(raw.text, "html.parser")
    
    articles = html.select("ul.type01>li")
    
    for ar in articles:
        title = ar.select_one("a._sp_each_title").text.strip().replace(',','_')
        source = ar.select_one("span._sp_each_source").text.strip().replace(',','_')
        # 출력 및 파일 지정 양식에 검색어 추가
        print(keyword, ':', title, source)
        sheet.append([keyword, title, source])
        
wb.save('naver_keyword_news.xlsx')
# Out:
# 불러오기 완료
# 검색어를 입력하세요: 아이유
# 아이유 : 서초구_ 아이유 등 지역 주민들 방역물품 기부 뉴시스
# 아이유 : 아이유_ 코로나19 취약계층 감영 예방 위해 1억 쾌척 스포츠서울
# 아이유 : 아이유_ 서초구에 3천만원 전달…코로나 극복 주민 기부 이어져 연합뉴스
# 아이유 : 아이유_ 코로나19 성금으로 2억 원 쾌척...'기부 영웅' 영향력 ing YTN
# 아이유 : 가수 아이유_ 1억 상당 의료용 방호복 3000벌 의협에 기증 중앙일보
# 아이유 : "아이유도 참석" 패션업계 밀라노發 '코로나 패닉' 머니투데이언론사 선정
# 아이유 : 방탄소년단(BTS) 슈가·아이유 등 스타들 코로나19 확산 막기 위한 기부 동참... 스포츠경향
# 아이유 : 아이유_ 코로나19 확산 방지에 1억원 기부 일간스포츠
# 아이유 : 아이유_ 다정한 '일상 코치'로 변신…셀럽 알람 4차 버전 공개 스포츠조선
# 아이유 : [팩플]아이유 목소리 내게 말건다는데···'악당' 걱정은 커졌다 중앙일보언론사 선정
# 아이유 : 정려원·아이유_ 굿네이버스에 각각 1억원 기부…"코로나 극복" 연합뉴스
# 아이유 : 아이유_ 코로나19 확산 방지에 1억원 기부 일간스포츠
# 아이유 : 이서진-아이유_ 성실납세 홍보 나선다…국세청 홍보대사 위촉 뉴데일리
# 아이유 : 가수 아이유_ 코로나19 성금 2억 기부…˝방역 물품 및 방호복 지원˝ 경북신문
# 아이유 : 리사X아이유X로운X조이_ 세계 패션위크 빛낸 스타들 일간스포츠
# 아이유 : 아이유_ 다정한 '일상 코치'로 변신…셀럽 알람 4차 버전 공개 스포츠조선
# 아이유 : '77억의 사랑' 유인나 "아이유 때문에 결혼 못 할지도 모른다"... 이유는? 헤럴드POP
# 아이유 : 정우성부터 아이유까지... 끊임없는 코로나19 기부행렬 오마이뉴스
# 아이유 : 박주원 기타 이야기 #집시 #속주 #아이유[윤상근의 맥락] 스타뉴스
# 아이유 : [Y이슈] "코로나19 극복하자"...아이유·박명수·손예진·서장훈 등 기부 릴레... YTN
# 아이유 : 아이유 2억_ 봉준호 1억 ‘힘내요 대구’ 응원 쏟아진다 중앙일보
# 아이유 : 아이유_ 가온차트 주간 2관왕 등극..방탄소년단_ 앨범차트 1위 NSP통신
# 아이유 : [이슈] 사람이야 천사야…아이유_ 고등학생 때부터 미담 제조기 스포츠월드
# 아이유 : 송강호→손예진·아이유_ 연예계 선행ing…코로나19 성금 기부 적극 동참(종합... 뉴스1
# 아이유 : [EPL 리뷰] 'J.아이유 결승골' 팰리스_ 브라이튼 원정서 1-0 신승...2연승 인터풋볼
# 아이유 : 아이유 ‘코로나19’ 지원…의협에 의료용 방호복 기증 약사공론
# 아이유 : 아이유_ 핑크빛 드레스에 러블리+청순 매력 물씬 일간스포츠
# 아이유 : 안데스 지역의 원주민 '아이유' 공동체 문화: '두 개의 공화국' 가톨릭뉴스 지금여기
# 아이유 : [영상] 아이유 2억_ 박서준 1억 ... 코로나19에 기부 릴레이 뉴스1
# 아이유 : 유인나 "결혼 생각 자주 바뀌는 아이유…난 좋은 사람 있으면 할 것" ('77억의... 마이데일리
# 아이유 : 송희 “좋아하는 연예인은 아이유” [MK★사소한인터뷰-밴디트 편②] MK스포츠
# 아이유 : 아이유_ 아이돌차트 2월 2주차 아차랭킹 1위 한국경제TV
# 아이유 : 아이유_ 봄햇살 아래 상큼한 미소 가득 나빌레라[스타SNS] 스포츠서울
# 아이유 : 타케우치 미유_ 아이유 '밤편지' 열창…"유튜브가 너무 하고 싶어요" [in스타... 엑스포츠뉴스
# 아이유 : [SE★이슈]아이유부터 김혜수_ 수지_ 공유···코로나19 기부 릴레이 서울경제
# 아이유 : 아이유 측 "악의적 비방 누리꾼들 법적 조치 中" SBS funE
# 아이유 : 아이유_ ‘두근:대결구도’ 이상형월드컵서 우승 추가… 누적 28번째 엑스포츠뉴스
# 아이유 : 아이유 측 "악플러 신원 확보…순차적 처벌 진행 중" (공식) YTN
# 아이유 : [DAY컷] 아이유_ 싱그러움 가득 과즙 美 스포츠동아
# 아이유 : "선 넘으면 침범" 아이유_ SNS 해킹시도 '경고' 일간스포츠
# 아이유 : [뉴스1 PICK]아이유 '예쁨 뿜뿜' 공항 패션 뉴스1
# 아이유 : 이효리 잘만난 이천희_ 가구 어떻기에…'효리네' 아이유 낮잠 의자‧윤아 테이... 스포티비뉴스
# 아이유 : 아이유_ 민트 재킷 입고 봄요정으로 변신 '아이민트유♥' 엑스포츠뉴스
# 아이유 : 손예진·아이유·김연아.._ 위기 속 온기전하는 ★들의 기부 enews24
# 아이유 : 아이유_ 달콤한 봄의 요정으로 변신... 사랑스러움 가득 스타데일리뉴스
# 아이유 : 아이유_ 밀라노 밝히는 눈부신 미모 ‘러블리’ 매일경제
# 아이유 : 방탄소년단_ ‘MAP OF THE SOUL : 7’ 가온 앨범차트 1위..아이유 2관왕 브레이크뉴스
# 아이유 : 아이유_ 15일 '사랑의 불시착' OST '마음을 드려요' 음원 발매 YTN
# 아이유 : "코로나19 이겨내세요"…아이유→송중기→봉준호→박명수_ 기부 나선 ★ [종합... OSEN
# 아이유 : '힘내요 대구·경북' 아이유·김희선·BTS 슈가·봉준호 등 스타들 코로나19 ... 업다운뉴스
# 아이유 : [S톡] 아이유_ 이래서 아이유 스타데일리뉴스
# 아이유 : 방탄소년단_ 아차랭킹 1위 탈환..아이즈원-아이유-레드벨벳 상위권 차지 브레이크뉴스
# 아이유 : [포토] 아이유 '그윽한 시선' 일간스포츠
# 아이유 : [포토] 아이유 '격자무늬 여신' 일간스포츠
# 아이유 : [포토] 아이유 '정갈한 착지' 일간스포츠
# 아이유 : “요정 강림” 아이유_ 명품으로 무장한 공항패션 서울신문
# 아이유 : [포토] 아이유 '사랑이 담긴 흘깃' 일간스포츠
# 아이유 : [포토] 아이유 '본죠르노 밀라노' 일간스포츠
# 아이유 : [포토] 아이유 '아주 잠시만 아디오' 일간스포츠
# 아이유 : [포토] 아이유 '치명적인 매력' 일간스포츠
# 아이유 : 아이유·박명수·서장훈…오늘도 계속되는 스타들 기부행렬 국민일보
# 아이유 : 아이유 화보 공개_ 고혹미에 싱그러운 매력까지' 무한 매력 발산 매일신문
# 아이유 : ‘공항 여신’ 아이유의 손하트 스포츠동아
# 아이유 : ‘아이유ㆍ김희선 2억ㆍ김연아 1억’ 코로나19 극복 돕기 위한 기부 릴레이 한국일보
# 아이유 : [포토] 아이유 '눈부신 출국신고' 일간스포츠
# 아이유 : [포토] 아이유 '저도 밀라노 갑니다' 일간스포츠
# 아이유 : [포토] 아이유 '청초한 이지은' 일간스포츠
# 아이유 : 아이유 측 “악플러 순차적으로 처벌 중…법적 대응 지속할 것” [공식] 스포츠경향
# 아이유 : [포토] 아이유 '머리만 살짝 넘겼을 뿐' 일간스포츠
# 아이유 : [포토] 아이유 '봄미소 머금고 신호대기' 일간스포츠
# 아이유 : [포토] 아이유 '사랑을 담아 물끄러미' 일간스포츠
# 아이유 : [포토] 아이유_ 하트 스포츠조선
# 아이유 : 아이유_ '사랑의 불시착'으로 9년 만의 OST 참여 YTN
# 아이유 : [포토] 아이유_ '심쿵!' 스포츠조선
# 아이유 : [포토] 아이유 '밀라노 다녀올게요' 일간스포츠
# 아이유 : [포토] 아이유_ 설레는 발걸음 스포츠조선
# 아이유 : [매일 연예돋보기] 악플과의 전쟁…아이유 '강경 대응' 매일신문
# 아이유 : 아이유(IU)_ "지은이 하트 받아가세요" [공항패션] 엑스포츠뉴스
# 아이유 : 아이유_ 요정의 인사 뉴스1
# 아이유 : 아이유_ 예뻐도 너무 예쁘네…요정인 줄 매일경제
# 아이유 : 아이유_ 밀라노 밝히는 ‘바비인형’ 한국일보
# 아이유 : [포토] 아이유 '조금만 참아요. 봄 데리고 올게요' 일간스포츠
# 아이유 : 아이유_ 예쁜 손인사 뉴스1
# 아이유 : 아이유_ 하트에 녹네 녹아 뉴스1
# 아이유 : 아이유_ 앵두같은 입술 뉴스1
# 아이유 : 아이유_ 구찌쇼 전 '숨멎' 비주얼…'여.신.강.림' 엑스포츠뉴스
# 아이유 : 코로나19 극복_ 손예진·서장훈·송중기·아이유 스타들의 기부 릴레이 여성조선
# 아이유 : "함께 극복" 손예진·소유진→김요한·아이유…코로나19 사태에 기부 행렬ing... 엑스포츠뉴스
# 아이유 : [포토] 아이유_ '오늘도 러블리~' 스포츠조선
# 아이유 : [포토] 아이유_ 머리만 살짝 넘겨도~ 스포츠조선
# 아이유 : [포토] 아이유_ '우아한 인사' 스포츠조선
# 아이유 : 아이유_ 옆모습도 예술 뉴스1
# 아이유 : [TD영상] 아이유 '마주치면 심쿵!' 티브이데일리
# 아이유 : 아이유 (IU)_ 이 하트 소장각 (인천공항) [SS쇼캠] 스포츠서울
# 아이유 : [포토] 아이유_ 포즈를 아는 소녀 스포츠조선
# 아이유 : [E포토]아이유_ '횡단보도 런웨이' SBS funE
# 아이유 : “선 넘으면 침범” 아이유_ SNS 해킹에 강력한 경고 스포츠경향
# 아이유 : 아이유_ 망또가 잘 어울리는 '귀여운 외모' 스냅
# 아이유 : [E포토]아이유_ '추위도 잊게 만드는 미모' SBS funE
# 아이유 : [E포토]아이유_ '화려한 명품 공항패션' SBS funE
