# %% [markdown]
# ## 네이버 영화 데이터 수집하기

# %% [markdown]
# #### 같은 선택자를 가지고 있는 데이터를 분리해서 수집할 수 있는 방법
# 1. 리스트 활용하기
#     - select 함수를 사용해 데이터를 리스트 형태로 저장한 뒤, 리스트에 저장된 데이터를 인덱싱하여 특정 순서의 데이터를 수집할 수 있습니다.
#     - 아래 예시에서 각 dd태그 안의 a 태그에 장르, 감독, 배우에 대한 데이터가 들어있고, 한 영화에 여러 개의 장르, 감독, 배우에 대한 데이터가 있을 수 있으므로 select 함수를 사용해서 리스트로 저장합니다.

# %%
import requests
from bs4 import BeautifulSoup
raw= requests.get("https://movie.naver.com/movie/running/current.nhn",
                  headers={'User-Agent': 'Morzilla/5.0'})
html = BeautifulSoup(raw.text,'html.parser')

movies = html.select("dl.lst_dsc")
for m in movies:
    title = m.select_one('dt.tit>a').text
    score = m.select_one('div.star_t1 span.num').text
    # 예매율도 평점과 같은 선택자이지만 select_one은 첫번째 데이터를 가져오므로 상관 없음

# 장르/감독/배우 --> dl.info_text1 dd a
    # 이 때 한 영화에 여러 장르, 감독, 배우가 있을 수 있으므로 select 함수 사용
    try:
        info = m.select('dl.info_txt1 dd')
        genre = info[0].select('a')
        director = info[1].select('a')
        actor = info[2].select('a')
    except:
        info = m.select('dl.info_txt1 dd')
        genre = info[0].select('a')
        director = info[1].select('a')

    print('제목:', title)
    print('평점:', score)
    # 장르, 감독, 배우는 데이터가 여러개일 수 있으므로 반복문을 통해 출력
    print('장르:')
    for g in genre:
        print(g.text)
    print('감독:')
    for d in director:
        print(d.text)
    print('배우:')
    for a in actor:
        print(a.text)
    print('='*50)
# Out:
# 제목: 인비저블맨
# 평점: 8.34
# 장르:
# 공포
# 스릴러
# 감독:
# 리 워넬
# 배우:
# 엘리자베스 모스
# ==================================================
# 제목: 지푸라기라도 잡고 싶은 짐승들
# 평점: 6.67
# 장르:
# 범죄
# 스릴러
# 감독:
# 김용훈
# 배우:
# 전도연
# 정우성
# 배성우
# 윤여정
# 정만식
# 진경
# 신현빈
# 정가람
# ==================================================
# 제목: 1917
# 평점: 8.98
# 장르:
# 드라마
# 전쟁
# 감독:
# 샘 멘데스
# 배우:
# 조지 맥케이
# 딘-찰스 채프먼
# ==================================================
# 제목: 정직한 후보
# 평점: 7.70
# 장르:
# 코미디
# 감독:
# 장유정
# 배우:
# 라미란
# 김무열
# 나문희
# 윤경호
# ==================================================
# 제목: 작은 아씨들
# 평점: 8.88
# 장르:
# 드라마
# 멜로/로맨스
# 감독:
# 그레타 거윅
# 배우:
# 시얼샤 로넌
# 엠마 왓슨
# 플로렌스 퓨
# 엘리자 스캔런
# 티모시 샬라메
# ==================================================
# 제목: 젠틀맨
# 평점: 8.51
# 장르:
# 범죄
# 액션
# 감독:
# 가이 리치
# 배우:
# 매튜 맥커너히
# 휴 그랜트
# 콜린 파렐
# 찰리 허냄
# 헨리 골딩
# 미셀 도커리
# ==================================================
# 제목: 시원찮은 그녀를 위한 육성방법 피날레
# 평점: 8.42
# 장르:
# 애니메이션
# 드라마
# 감독:
# 카메이 칸타
# 배우:
# 마츠오카 요시츠구
# 야스노 키요노
# 오오니시 사오리
# 카야노 아이
# 야하기 사유리
# ==================================================
# 제목: 장마
# 평점: 9.70
# 장르:
# 다큐멘터리
# 감독:
# 이용남
# 음정현
# 배우:
# 이은택
# ==================================================
# 제목: 클로젯
# 평점: 6.86
# 장르:
# 미스터리
# 드라마
# 감독:
# 김광빈
# 배우:
# 하정우
# 김남길
# 허율
# 김시아
# ==================================================
# 제목: 조조 래빗
# 평점: 9.21
# 장르:
# 코미디
# 드라마
# 전쟁
# 감독:
# 타이카 와이티티
# 배우:
# 스칼렛 요한슨
# 로만 그리핀 데이비스
# 타이카 와이티티
# 토마신 맥켄지
# ==================================================
# 제목: 기생충
# 평점: 8.48
# 장르:
# 드라마
# 감독:
# 봉준호
# 배우:
# 송강호
# 이선균
# 조여정
# 최우식
# 박소담
# 이정은
# 장혜진
# ==================================================
# 제목: 하이, 젝시
# 평점: 6.64
# 장르:
# 코미디
# 감독:
# 존 루카스
# 스캇 무어
# 배우:
# 아담 드바인
# 로즈 번
# ==================================================
# 제목: 숀더쉽 더 무비: 꼬마 외계인 룰라!
# 평점: 9.35
# 장르:
# 애니메이션
# 모험
# 코미디
# 감독:
# 윌 베처
# 리처드 펠런
# 배우:
# 저스틴 플레쳐
# 아멜리아 비테일
# ==================================================
# 제목: 수퍼 소닉
# 평점: 8.41
# 장르:
# 애니메이션
# 액션
# 모험
# 코미디
# 가족
# 판타지
# SF
# 감독:
# 제프 파울러
# 배우:
# 짐 캐리
# 제임스 마스던
# 벤 슈와츠
# 티카 섬터
# ==================================================
# 제목: 타오르는 여인의 초상
# 평점: 9.03
# 장르:
# 드라마
# 감독:
# 셀린 시아마
# 배우:
# 아델 하에넬
# 노에미 메를랑
# 루아나 바야미
# 발레리아 골리노
# ==================================================
# 제목: 작가 미상
# 평점: 9.14
# 장르:
# 드라마
# 스릴러
# 감독:
# 플로리안 헨켈 폰 도너스마르크
# 배우:
# 톰 쉴링
# 폴라 비어
# 세바스티안 코치
# ==================================================
# 제목: 샤인
# 평점: 9.07
# 장르:
# 드라마
# 멜로/로맨스
# 감독:
# 스콧 힉스
# 배우:
# 제프리 러쉬
# 노아 테일러
# ==================================================
# 제목: 버즈 오브 프레이(할리 퀸의 황홀한 해방)
# 평점: 6.74
# 장르:
# 액션
# 모험
# 범죄
# 감독:
# 캐시 얀
# 배우:
# 마고 로비
# ==================================================
# 제목: 극장판 미니특공대: 공룡왕 디노
# 평점: 9.27
# 장르:
# 애니메이션
# 감독:
# 이영준
# 배우:
# 신용우
# 엄상현
# 이소영
# 전태열
# 양정화
# ==================================================
# 제목: 남산의 부장들
# 평점: 7.43
# 장르:
# 드라마
# 감독:
# 우민호
# 배우:
# 이병헌
# 이성민
# 곽도원
# 이희준
# 김소진
# ==================================================
# 제목: 빈폴
# 평점: 9.36
# 장르:
# 드라마
# 감독:
# 칸테미르 발라고프
# 배우:
# 빅토리아 미로시니첸코
# 바실리사 페렐리지나
# ==================================================
# 제목: 나이브스 아웃
# 평점: 9.11
# 장르:
# 미스터리
# 스릴러
# 감독:
# 라이언 존슨
# 배우:
# 다니엘 크레이그
# 크리스 에반스
# 아나 디 아르마스
# 제이미 리 커티스
# 토니 콜렛
# 마이클 섀넌
# 돈 존슨
# 키스 스탠필드
# 캐서린 랭포드
# 제이든 마텔
# 크리스토퍼 플러머
# ==================================================
# 제목: 기억의 전쟁
# 평점: 9.50
# 장르:
# 다큐멘터리
# 감독:
# 이길보라
# 배우:
# 응우옌 티 탄
# 응우옌 럽
# 딘 껌
# 응우옌 티 탄
# ==================================================
# 제목: 포드 V 페라리
# 평점: 9.51
# 장르:
# 액션
# 드라마
# 감독:
# 제임스 맨골드
# 배우:
# 맷 데이먼
# 크리스찬 베일
# ==================================================
# 제목: 엠마
# 평점: 8.50
# 장르:
# 코미디
# 드라마
# 멜로/로맨스
# 감독:
# 어텀 드 와일드
# 배우:
# 안야 테일러 조이
# ==================================================
# 제목: 페인 앤 글로리
# 평점: 8.09
# 장르:
# 드라마
# 감독:
# 페드로 알모도바르
# 배우:
# 페넬로페 크루즈
# 안토니오 반데라스
# ==================================================
# 제목: 더 테러리스트
# 평점: 7.50
# 장르:
# 범죄
# 스릴러
# 감독:
# 예민 엘퍼
# 배우:
# 메멧 오즈구르
# 베르카이 아테스
# ==================================================
# 제목: 하이큐!! 땅 VS 하늘
# 평점: 8.45
# 장르:
# 애니메이션
# 감독:
# 미츠나카 스스무
# 배우:
# 나카무라 유이치
# 카지 유우키
# ==================================================
# 제목: 극장판 원피스 스탬피드
# 평점: 8.93
# 장르:
# 모험
# 액션
# 판타지
# 애니메이션
# 감독:
# 오츠카 타카시
# 배우:
# 타나카 마유미
# 나카이 카즈야
# 오카무라 아케미
# 야마구치 캇페이
# ==================================================
# 제목: 집에 돌아오면, 언제나 아내가 죽은 척을 하고 있다
# 평점: 6.47
# 장르:
# 드라마
# 코미디
# 멜로/로맨스
# 감독:
# 리 토시오
# 배우:
# 에이쿠라 나나
# 야스다 켄
# ==================================================
# 제목: 기도하는 남자
# 평점: 8.45
# 장르:
# 드라마
# 범죄
# 감독:
# 강동헌
# 배우:
# 박혁권
# 류현경
# 남기애
# ==================================================
# 제목: 문신을 한 신부님
# 평점: 8.68
# 장르:
# 드라마
# 감독:
# 얀 코마사
# 배우:
# 바르토시 비엘레니아
# ==================================================
# 제목: 사마에게
# 평점: 9.20
# 장르:
# 다큐멘터리
# 감독:
# 와드 알-카팁
# 에드워드 와츠
# 배우:
# 와드 알-카팁
# 사마 알-카팁
# 함자 알-카팁
# ==================================================
# 제목: 날씨의 아이
# 평점: 7.90
# 장르:
# 애니메이션
# 감독:
# 신카이 마코토
# 배우:
# 다이고 코타로
# 모리 나나
# 오구리 슌
# ==================================================
# 제목: 벌새
# 평점: 8.81
# 장르:
# 드라마
# 감독:
# 김보라
# 배우:
# 박지후
# 김새벽
# ==================================================
# 제목: 하트
# 평점: 8.33
# 장르:
# 드라마
# 멜로/로맨스
# 감독:
# 정가영
# 배우:
# 정가영
# 이석형
# 최태환
# ==================================================
# 제목: 겨울왕국 2
# 평점: 8.70
# 장르:
# 애니메이션
# 모험
# 코미디
# 가족
# 판타지
# 뮤지컬
# 감독:
# 크리스 벅
# 제니퍼 리
# 배우:
# 크리스틴 벨
# 이디나 멘젤
# ==================================================
# 제목: 인셉션
# 평점: 9.23
# 장르:
# 액션
# 모험
# SF
# 스릴러
# 감독:
# 크리스토퍼 놀란
# 배우:
# 레오나르도 디카프리오
# 와타나베 켄
# 조셉 고든 레빗
# 마리옹 꼬띠아르
# 엘렌 페이지
# 톰 하디
# ==================================================
# 제목: 이 멋진 세계에 축복을! 붉은 전설
# 평점: 8.37
# 장르:
# 애니메이션
# 액션
# 판타지
# 코미디
# 감독:
# 카나사키 타카오미
# 배우:
# 후쿠시마 준
# 아마미야 소라
# 타카하시 리에
# 카야노 아이
# 토요사키 아키
# ==================================================
# 제목: 히트맨
# 평점: 6.93
# 장르:
# 코미디
# 액션
# 감독:
# 최원섭
# 배우:
# 권상우
# 정준호
# 황우슬혜
# 이이경
# 이지원
# ==================================================
# 제목: 시호
# 평점: 7.75
# 장르:
# 멜로/로맨스
# 감독:
# 홍수동
# 배우:
# 신은경
# 윤희석
# 도우
# ==================================================
# 제목: 피아니스트의 전설
# 평점: 9.25
# 장르:
# 드라마
# 판타지
# 뮤지컬
# 감독:
# 쥬세페 토르나토레
# 배우:
# 팀 로스
# 프루이트 테일러 빈스
# ==================================================
# 제목: 카잔자키스
# 평점: 7.47
# 장르:
# 감독:
# 야니스 스마라그디스
# 배우:
# 오디세즈 파파스필리오풀로스
# 마리나 칼로기루
# 토도리스 아테리디스
# ==================================================
# 제목: 윤희에게
# 평점: 8.94
# 장르:
# 멜로/로맨스
# 감독:
# 임대형
# 배우:
# 김희애
# 김소혜
# 성유빈
# 나카무라 유코
# 키노 하나
# ==================================================
# 제목: 울지마 톤즈 2 : 슈크란 바바
# 평점: 9.60
# 장르:
# 다큐멘터리
# 감독:
# 강성옥
# 배우:
# 이금희
# 이태석
# ==================================================
# 제목: 성혜의 나라
# 평점: 8.13
# 장르:
# 드라마
# 감독:
# 정형석
# 배우:
# 송지인
# 강두
# ==================================================
# 제목: 아이리시맨
# 평점: 8.79
# 장르:
# 범죄
# 드라마
# 스릴러
# 감독:
# 마틴 스코세이지
# 배우:
# 로버트 드 니로
# 알 파치노
# 조 페시
# ==================================================
# 제목: 에릭 클랩튼: 기타의 신
# 평점: 8.12
# 장르:
# 다큐멘터리
# 감독:
# 릴리 피니 자눅
# 배우:
# 에릭 클랩튼
# ==================================================
# 제목: 결혼 이야기
# 평점: 9.07
# 장르:
# 코미디
# 드라마
# 감독:
# 노아 바움백
# 배우:
# 스칼렛 요한슨
# 아담 드라이버
# ==================================================
# 제목: 파바로티
# 평점: 9.04
# 장르:
# 다큐멘터리
# 감독:
# 론 하워드
# 배우:
# 루치아노 파바로티
# ==================================================
# 제목: 라붐
# 평점: 8.00
# 장르:
# 드라마
# 멜로/로맨스
# 코미디
# 감독:
# 클로드 피노토
# 배우:
# 소피 마르소
# 클로드 브라소
# 브리지트 포시
# ==================================================
# 제목: 그린 북
# 평점: 9.60
# 장르:
# 드라마
# 감독:
# 피터 패럴리
# 배우:
# 비고 모텐슨
# 마허샬라 알리
# ==================================================
# 제목: 실버라이닝 플레이북
# 평점: 8.59
# 장르:
# 코미디
# 드라마
# 멜로/로맨스
# 감독:
# 데이비드 O. 러셀
# 배우:
# 제니퍼 로렌스
# 브래들리 쿠퍼
# 로버트 드 니로
# 크리스 터커
# ==================================================
# 제목: 아이 필 프리티
# 평점: 8.58
# 장르:
# 코미디
# 감독:
# 에비 콘
# 마크 실버스테인
# 배우:
# 에이미 슈머
# 미셸 윌리엄스
# ==================================================
# 제목: 원더
# 평점: 9.49
# 장르:
# 드라마
# 감독:
# 스티븐 크보스키
# 배우:
# 제이콥 트렘블레이
# 줄리아 로버츠
# 오웬 윌슨
# 이자벨라 비도빅
# ==================================================
# 제목: 리틀 포레스트
# 평점: 8.78
# 장르:
# 드라마
# 감독:
# 임순례
# 배우:
# 김태리
# 류준열
# 문소리
# 진기주
# ==================================================
# 제목: 더 킹: 헨리 5세
# 평점: 8.48
# 장르:
# 드라마
# 감독:
# 데이비드 미쇼
# 배우:
# 티모시 샬라메
# 조엘 에저튼
# ==================================================
# 제목: 로마
# 평점: 9.04
# 장르:
# 드라마
# 감독:
# 알폰소 쿠아론
# 배우:
# 얄리차 아파리시오
# 마리나 데 타비라
# ==================================================
# 제목: 두 교황
# 평점: 9.35
# 장르:
# 드라마
# 감독:
# 페르난도 메이렐레스
# 배우:
# 안소니 홉킨스
# 조나단 프라이스
# ==================================================
# 제목: 해리 포터와 아즈카반의 죄수
# 평점: 8.68
# 장르:
# 판타지
# 가족
# 모험
# 액션
# 감독:
# 알폰소 쿠아론
# 배우:
# 다니엘 래드클리프
# 엠마 왓슨
# 루퍼트 그린트
# ==================================================
# 제목: 미스터 주: 사라진 VIP
# 평점: 4.48
# 장르:
# 코미디
# 드라마
# 감독:
# 김태윤
# 배우:
# 이성민
# 김서형
# 배정남
# 신하균
# ==================================================
# 제목: 졸업
# 평점: 8.54
# 장르:
# 드라마
# 코미디
# 감독:
# 마이크 니콜스
# 배우:
# 앤 밴크로프트
# 더스틴 호프만
# 캐서린 로스
# ==================================================
# 제목: 작은 빛
# 평점: 7.04
# 장르:
# 드라마
# 감독:
# 조민재
# 배우:
# 곽진무
# 신문성
# 변중희
# 김현
# ==================================================
# 제목: 몽마르트 파파
# 평점: 9.56
# 장르:
# 다큐멘터리
# 감독:
# 민병우
# 배우:
# 민형식
# 이운숙
# 민병우
# ==================================================
# 제목: 울지마 톤즈
# 평점: 9.35
# 장르:
# 다큐멘터리
# 감독:
# 구수환
# 배우:
# 이금희
# 이태석
# ==================================================
# 제목: 조커
# 평점: 8.65
# 장르:
# 스릴러
# 드라마
# 감독:
# 토드 필립스
# 배우:
# 호아킨 피닉스
# ==================================================
# 제목: 주전장
# 평점: 9.52
# 장르:
# 다큐멘터리
# 감독:
# 미키 데자키
# 배우:
# 호아킨 피닉스
# ==================================================
# 제목: 파리로 가는 길
# 평점: 7.89
# 장르:
# 드라마
# 멜로/로맨스
# 감독:
# 엘레노어 코폴라
# 배우:
# 다이안 레인
# 알렉 볼드윈
# 아르노 비야르
# ==================================================
# 제목: 혼 : 공포의 시작
# 평점: 4.68
# 장르:
# 공포
# 감독:
# 유성호
# 배우:
# 옥지영
# 최규환
# 김승현
# 지이수
# 최제우
# 이달형
# ==================================================
# 제목: 다운폴
# 평점: 9.00
# 장르:
# 전쟁
# 드라마
# 감독:
# 올리버 히르비겔
# 배우:
# 브루노 간츠
# 알렉산드라 마리아 라라
# 코리나 하르포히
# 울리히 마트데스
# 율리안느 콜러
# 헤이노 페르치
# 크리스찬 버켈
# ==================================================
# 제목: 더 파티
# 평점: 8.07
# 장르:
# 코미디
# 드라마
# 감독:
# 샐리 포터
# 배우:
# 크리스틴 스콧 토마스
# 패트리시아 클락슨
# 킬리언 머피
# 티모시 스폴
# 브루노 강쯔
# 체리 존스
# 에밀리 모티머
# ==================================================
# 제목: 미스 사이공: 25주년 특별 공연
# 평점: 9.18
# 장르:
# 공연실황
# 감독:
# 브렛 설리반
# 배우:
# 알리스태어 브래머
# 에바 노블자다
# 홍광호
# 존 존 브라이언스
# ==================================================
# 제목: 베를린 천사의 시
# 평점: 8.65
# 장르:
# 판타지
# 드라마
# 멜로/로맨스
# 감독:
# 빔 벤더스
# 배우:
# 브루노 간츠
# 솔베이그 도마르틴
# 오토 샌더
# ==================================================
# 제목: 비투스
# 평점: 8.94
# 장르:
# 드라마
# 감독:
# 프레디 M. 무러
# 배우:
# 브루노 강쯔
# 테오 게오르규
# ==================================================
# 제목: 영원과 하루
# 평점: 8.46
# 장르:
# 드라마
# 감독:
# 테오도로스 앙겔로플로스
# 배우:
# 브루노 간츠
# ==================================================

# %% [markdown]
# 2. 선택자 응용하기(nth-of-type)
#     - '태그이름:nth-of-type(n)'을 활용하면 n번째 태그 데이터를 선택할 수 있습니다. 프로그래밍 언어는 대부분 숫자 0부터 세지만 nth-of-type()의 경우는 숫자를 1부터 셉니다.
#     - 그리고 nth-of-type()의 앞에는 클래스 또는 아이디가 올 수 없기 때문에 해당하는 태그가 몇번째 태그인지도 꼭 확인해야 합니다.

# %%
import requests
from bs4 import BeautifulSoup
raw= requests.get("https://movie.naver.com/movie/running/current.nhn",
                  headers={'User-Agent': 'Morzilla/5.0'})
html = BeautifulSoup(raw.text,'html.parser')

movies = html.select("dl.lst_dsc")
for m in movies:
    title = m.select_one('dt.tit a')
    score = m.select_one('div.star_t1 span.num')
    # 장르/감독/배우 --> dl.info_text1 dd a
    # nth-of-type을 활용해서 데이터를 선택합니다.
    genre = m.select("dl.info_txt1 dd:nth-of-type(1) a")
    director = m.select("dl.info_txt1 dd:nth-of-type(2) a")
    actor = m.select("dl.info_txt1 dd:nth-of-type(3) a")

    print('제목:', title.text)
    print('평점:', score.text)
    print('장르:')
    for g in genre:
        print(g.text)
    print('감독:')
    for d in director:
        print(d.text)
    print('배우:')
    for a in actor:
        print(a.text)
    print('='*50)
# Out:
# 제목: 인비저블맨
# 평점: 8.34
# 장르:
# 공포
# 스릴러
# 감독:
# 리 워넬
# 배우:
# 엘리자베스 모스
# ==================================================
# 제목: 지푸라기라도 잡고 싶은 짐승들
# 평점: 6.67
# 장르:
# 범죄
# 스릴러
# 감독:
# 김용훈
# 배우:
# 전도연
# 정우성
# 배성우
# 윤여정
# 정만식
# 진경
# 신현빈
# 정가람
# ==================================================
# 제목: 1917
# 평점: 8.98
# 장르:
# 드라마
# 전쟁
# 감독:
# 샘 멘데스
# 배우:
# 조지 맥케이
# 딘-찰스 채프먼
# ==================================================
# 제목: 정직한 후보
# 평점: 7.70
# 장르:
# 코미디
# 감독:
# 장유정
# 배우:
# 라미란
# 김무열
# 나문희
# 윤경호
# ==================================================
# 제목: 작은 아씨들
# 평점: 8.88
# 장르:
# 드라마
# 멜로/로맨스
# 감독:
# 그레타 거윅
# 배우:
# 시얼샤 로넌
# 엠마 왓슨
# 플로렌스 퓨
# 엘리자 스캔런
# 티모시 샬라메
# ==================================================
# 제목: 젠틀맨
# 평점: 8.51
# 장르:
# 범죄
# 액션
# 감독:
# 가이 리치
# 배우:
# 매튜 맥커너히
# 휴 그랜트
# 콜린 파렐
# 찰리 허냄
# 헨리 골딩
# 미셀 도커리
# ==================================================
# 제목: 시원찮은 그녀를 위한 육성방법 피날레
# 평점: 8.42
# 장르:
# 애니메이션
# 드라마
# 감독:
# 카메이 칸타
# 배우:
# 마츠오카 요시츠구
# 야스노 키요노
# 오오니시 사오리
# 카야노 아이
# 야하기 사유리
# ==================================================
# 제목: 장마
# 평점: 9.70
# 장르:
# 다큐멘터리
# 감독:
# 이용남
# 음정현
# 배우:
# 이은택
# ==================================================
# 제목: 클로젯
# 평점: 6.86
# 장르:
# 미스터리
# 드라마
# 감독:
# 김광빈
# 배우:
# 하정우
# 김남길
# 허율
# 김시아
# ==================================================
# 제목: 조조 래빗
# 평점: 9.21
# 장르:
# 코미디
# 드라마
# 전쟁
# 감독:
# 타이카 와이티티
# 배우:
# 스칼렛 요한슨
# 로만 그리핀 데이비스
# 타이카 와이티티
# 토마신 맥켄지
# ==================================================
# 제목: 기생충
# 평점: 8.48
# 장르:
# 드라마
# 감독:
# 봉준호
# 배우:
# 송강호
# 이선균
# 조여정
# 최우식
# 박소담
# 이정은
# 장혜진
# ==================================================
# 제목: 하이, 젝시
# 평점: 6.64
# 장르:
# 코미디
# 감독:
# 존 루카스
# 스캇 무어
# 배우:
# 아담 드바인
# 로즈 번
# ==================================================
# 제목: 숀더쉽 더 무비: 꼬마 외계인 룰라!
# 평점: 9.35
# 장르:
# 애니메이션
# 모험
# 코미디
# 감독:
# 윌 베처
# 리처드 펠런
# 배우:
# 저스틴 플레쳐
# 아멜리아 비테일
# ==================================================
# 제목: 수퍼 소닉
# 평점: 8.41
# 장르:
# 애니메이션
# 액션
# 모험
# 코미디
# 가족
# 판타지
# SF
# 감독:
# 제프 파울러
# 배우:
# 짐 캐리
# 제임스 마스던
# 벤 슈와츠
# 티카 섬터
# ==================================================
# 제목: 타오르는 여인의 초상
# 평점: 9.03
# 장르:
# 드라마
# 감독:
# 셀린 시아마
# 배우:
# 아델 하에넬
# 노에미 메를랑
# 루아나 바야미
# 발레리아 골리노
# ==================================================
# 제목: 작가 미상
# 평점: 9.14
# 장르:
# 드라마
# 스릴러
# 감독:
# 플로리안 헨켈 폰 도너스마르크
# 배우:
# 톰 쉴링
# 폴라 비어
# 세바스티안 코치
# ==================================================
# 제목: 샤인
# 평점: 9.07
# 장르:
# 드라마
# 멜로/로맨스
# 감독:
# 스콧 힉스
# 배우:
# 제프리 러쉬
# 노아 테일러
# ==================================================
# 제목: 버즈 오브 프레이(할리 퀸의 황홀한 해방)
# 평점: 6.74
# 장르:
# 액션
# 모험
# 범죄
# 감독:
# 캐시 얀
# 배우:
# 마고 로비
# ==================================================
# 제목: 극장판 미니특공대: 공룡왕 디노
# 평점: 9.27
# 장르:
# 애니메이션
# 감독:
# 이영준
# 배우:
# 신용우
# 엄상현
# 이소영
# 전태열
# 양정화
# ==================================================
# 제목: 남산의 부장들
# 평점: 7.43
# 장르:
# 드라마
# 감독:
# 우민호
# 배우:
# 이병헌
# 이성민
# 곽도원
# 이희준
# 김소진
# ==================================================
# 제목: 빈폴
# 평점: 9.36
# 장르:
# 드라마
# 감독:
# 칸테미르 발라고프
# 배우:
# 빅토리아 미로시니첸코
# 바실리사 페렐리지나
# ==================================================
# 제목: 나이브스 아웃
# 평점: 9.11
# 장르:
# 미스터리
# 스릴러
# 감독:
# 라이언 존슨
# 배우:
# 다니엘 크레이그
# 크리스 에반스
# 아나 디 아르마스
# 제이미 리 커티스
# 토니 콜렛
# 마이클 섀넌
# 돈 존슨
# 키스 스탠필드
# 캐서린 랭포드
# 제이든 마텔
# 크리스토퍼 플러머
# ==================================================
# 제목: 기억의 전쟁
# 평점: 9.50
# 장르:
# 다큐멘터리
# 감독:
# 이길보라
# 배우:
# 응우옌 티 탄
# 응우옌 럽
# 딘 껌
# 응우옌 티 탄
# ==================================================
# 제목: 포드 V 페라리
# 평점: 9.51
# 장르:
# 액션
# 드라마
# 감독:
# 제임스 맨골드
# 배우:
# 맷 데이먼
# 크리스찬 베일
# ==================================================
# 제목: 엠마
# 평점: 8.50
# 장르:
# 코미디
# 드라마
# 멜로/로맨스
# 감독:
# 어텀 드 와일드
# 배우:
# 안야 테일러 조이
# ==================================================
# 제목: 페인 앤 글로리
# 평점: 8.09
# 장르:
# 드라마
# 감독:
# 페드로 알모도바르
# 배우:
# 페넬로페 크루즈
# 안토니오 반데라스
# ==================================================
# 제목: 더 테러리스트
# 평점: 7.50
# 장르:
# 범죄
# 스릴러
# 감독:
# 예민 엘퍼
# 배우:
# 메멧 오즈구르
# 베르카이 아테스
# ==================================================
# 제목: 하이큐!! 땅 VS 하늘
# 평점: 8.45
# 장르:
# 애니메이션
# 감독:
# 미츠나카 스스무
# 배우:
# 나카무라 유이치
# 카지 유우키
# ==================================================
# 제목: 극장판 원피스 스탬피드
# 평점: 8.93
# 장르:
# 모험
# 액션
# 판타지
# 애니메이션
# 감독:
# 오츠카 타카시
# 배우:
# 타나카 마유미
# 나카이 카즈야
# 오카무라 아케미
# 야마구치 캇페이
# ==================================================
# 제목: 집에 돌아오면, 언제나 아내가 죽은 척을 하고 있다
# 평점: 6.47
# 장르:
# 드라마
# 코미디
# 멜로/로맨스
# 감독:
# 리 토시오
# 배우:
# 에이쿠라 나나
# 야스다 켄
# ==================================================
# 제목: 기도하는 남자
# 평점: 8.45
# 장르:
# 드라마
# 범죄
# 감독:
# 강동헌
# 배우:
# 박혁권
# 류현경
# 남기애
# ==================================================
# 제목: 문신을 한 신부님
# 평점: 8.68
# 장르:
# 드라마
# 감독:
# 얀 코마사
# 배우:
# 바르토시 비엘레니아
# ==================================================
# 제목: 사마에게
# 평점: 9.20
# 장르:
# 다큐멘터리
# 감독:
# 와드 알-카팁
# 에드워드 와츠
# 배우:
# 와드 알-카팁
# 사마 알-카팁
# 함자 알-카팁
# ==================================================
# 제목: 날씨의 아이
# 평점: 7.90
# 장르:
# 애니메이션
# 감독:
# 신카이 마코토
# 배우:
# 다이고 코타로
# 모리 나나
# 오구리 슌
# ==================================================
# 제목: 벌새
# 평점: 8.81
# 장르:
# 드라마
# 감독:
# 김보라
# 배우:
# 박지후
# 김새벽
# ==================================================
# 제목: 하트
# 평점: 8.33
# 장르:
# 드라마
# 멜로/로맨스
# 감독:
# 정가영
# 배우:
# 정가영
# 이석형
# 최태환
# ==================================================
# 제목: 겨울왕국 2
# 평점: 8.70
# 장르:
# 애니메이션
# 모험
# 코미디
# 가족
# 판타지
# 뮤지컬
# 감독:
# 크리스 벅
# 제니퍼 리
# 배우:
# 크리스틴 벨
# 이디나 멘젤
# ==================================================
# 제목: 인셉션
# 평점: 9.23
# 장르:
# 액션
# 모험
# SF
# 스릴러
# 감독:
# 크리스토퍼 놀란
# 배우:
# 레오나르도 디카프리오
# 와타나베 켄
# 조셉 고든 레빗
# 마리옹 꼬띠아르
# 엘렌 페이지
# 톰 하디
# ==================================================
# 제목: 이 멋진 세계에 축복을! 붉은 전설
# 평점: 8.37
# 장르:
# 애니메이션
# 액션
# 판타지
# 코미디
# 감독:
# 카나사키 타카오미
# 배우:
# 후쿠시마 준
# 아마미야 소라
# 타카하시 리에
# 카야노 아이
# 토요사키 아키
# ==================================================
# 제목: 히트맨
# 평점: 6.93
# 장르:
# 코미디
# 액션
# 감독:
# 최원섭
# 배우:
# 권상우
# 정준호
# 황우슬혜
# 이이경
# 이지원
# ==================================================
# 제목: 시호
# 평점: 7.75
# 장르:
# 멜로/로맨스
# 감독:
# 홍수동
# 배우:
# 신은경
# 윤희석
# 도우
# ==================================================
# 제목: 피아니스트의 전설
# 평점: 9.25
# 장르:
# 드라마
# 판타지
# 뮤지컬
# 감독:
# 쥬세페 토르나토레
# 배우:
# 팀 로스
# 프루이트 테일러 빈스
# ==================================================
# 제목: 카잔자키스
# 평점: 7.47
# 장르:
# 감독:
# 야니스 스마라그디스
# 배우:
# 오디세즈 파파스필리오풀로스
# 마리나 칼로기루
# 토도리스 아테리디스
# ==================================================
# 제목: 윤희에게
# 평점: 8.94
# 장르:
# 멜로/로맨스
# 감독:
# 임대형
# 배우:
# 김희애
# 김소혜
# 성유빈
# 나카무라 유코
# 키노 하나
# ==================================================
# 제목: 울지마 톤즈 2 : 슈크란 바바
# 평점: 9.60
# 장르:
# 다큐멘터리
# 감독:
# 강성옥
# 배우:
# 이금희
# 이태석
# ==================================================
# 제목: 성혜의 나라
# 평점: 8.13
# 장르:
# 드라마
# 감독:
# 정형석
# 배우:
# 송지인
# 강두
# ==================================================
# 제목: 아이리시맨
# 평점: 8.79
# 장르:
# 범죄
# 드라마
# 스릴러
# 감독:
# 마틴 스코세이지
# 배우:
# 로버트 드 니로
# 알 파치노
# 조 페시
# ==================================================
# 제목: 에릭 클랩튼: 기타의 신
# 평점: 8.12
# 장르:
# 다큐멘터리
# 감독:
# 릴리 피니 자눅
# 배우:
# 에릭 클랩튼
# ==================================================
# 제목: 결혼 이야기
# 평점: 9.07
# 장르:
# 코미디
# 드라마
# 감독:
# 노아 바움백
# 배우:
# 스칼렛 요한슨
# 아담 드라이버
# ==================================================
# 제목: 파바로티
# 평점: 9.04
# 장르:
# 다큐멘터리
# 감독:
# 론 하워드
# 배우:
# 루치아노 파바로티
# ==================================================
# 제목: 라붐
# 평점: 8.00
# 장르:
# 드라마
# 멜로/로맨스
# 코미디
# 감독:
# 클로드 피노토
# 배우:
# 소피 마르소
# 클로드 브라소
# 브리지트 포시
# ==================================================
# 제목: 그린 북
# 평점: 9.60
# 장르:
# 드라마
# 감독:
# 피터 패럴리
# 배우:
# 비고 모텐슨
# 마허샬라 알리
# ==================================================
# 제목: 실버라이닝 플레이북
# 평점: 8.59
# 장르:
# 코미디
# 드라마
# 멜로/로맨스
# 감독:
# 데이비드 O. 러셀
# 배우:
# 제니퍼 로렌스
# 브래들리 쿠퍼
# 로버트 드 니로
# 크리스 터커
# ==================================================
# 제목: 아이 필 프리티
# 평점: 8.58
# 장르:
# 코미디
# 감독:
# 에비 콘
# 마크 실버스테인
# 배우:
# 에이미 슈머
# 미셸 윌리엄스
# ==================================================
# 제목: 원더
# 평점: 9.49
# 장르:
# 드라마
# 감독:
# 스티븐 크보스키
# 배우:
# 제이콥 트렘블레이
# 줄리아 로버츠
# 오웬 윌슨
# 이자벨라 비도빅
# ==================================================
# 제목: 리틀 포레스트
# 평점: 8.78
# 장르:
# 드라마
# 감독:
# 임순례
# 배우:
# 김태리
# 류준열
# 문소리
# 진기주
# ==================================================
# 제목: 더 킹: 헨리 5세
# 평점: 8.48
# 장르:
# 드라마
# 감독:
# 데이비드 미쇼
# 배우:
# 티모시 샬라메
# 조엘 에저튼
# ==================================================
# 제목: 로마
# 평점: 9.04
# 장르:
# 드라마
# 감독:
# 알폰소 쿠아론
# 배우:
# 얄리차 아파리시오
# 마리나 데 타비라
# ==================================================
# 제목: 두 교황
# 평점: 9.35
# 장르:
# 드라마
# 감독:
# 페르난도 메이렐레스
# 배우:
# 안소니 홉킨스
# 조나단 프라이스
# ==================================================
# 제목: 해리 포터와 아즈카반의 죄수
# 평점: 8.68
# 장르:
# 판타지
# 가족
# 모험
# 액션
# 감독:
# 알폰소 쿠아론
# 배우:
# 다니엘 래드클리프
# 엠마 왓슨
# 루퍼트 그린트
# ==================================================
# 제목: 미스터 주: 사라진 VIP
# 평점: 4.48
# 장르:
# 코미디
# 드라마
# 감독:
# 김태윤
# 배우:
# 이성민
# 김서형
# 배정남
# 신하균
# ==================================================
# 제목: 졸업
# 평점: 8.54
# 장르:
# 드라마
# 코미디
# 감독:
# 마이크 니콜스
# 배우:
# 앤 밴크로프트
# 더스틴 호프만
# 캐서린 로스
# ==================================================
# 제목: 작은 빛
# 평점: 7.04
# 장르:
# 드라마
# 감독:
# 조민재
# 배우:
# 곽진무
# 신문성
# 변중희
# 김현
# ==================================================
# 제목: 몽마르트 파파
# 평점: 9.56
# 장르:
# 다큐멘터리
# 감독:
# 민병우
# 배우:
# 민형식
# 이운숙
# 민병우
# ==================================================
# 제목: 울지마 톤즈
# 평점: 9.35
# 장르:
# 다큐멘터리
# 감독:
# 구수환
# 배우:
# 이금희
# 이태석
# ==================================================
# 제목: 조커
# 평점: 8.65
# 장르:
# 스릴러
# 드라마
# 감독:
# 토드 필립스
# 배우:
# 호아킨 피닉스
# ==================================================
# 제목: 주전장
# 평점: 9.52
# 장르:
# 다큐멘터리
# 감독:
# 미키 데자키
# 배우:
# ==================================================
# 제목: 파리로 가는 길
# 평점: 7.89
# 장르:
# 드라마
# 멜로/로맨스
# 감독:
# 엘레노어 코폴라
# 배우:
# 다이안 레인
# 알렉 볼드윈
# 아르노 비야르
# ==================================================
# 제목: 혼 : 공포의 시작
# 평점: 4.68
# 장르:
# 공포
# 감독:
# 유성호
# 배우:
# 옥지영
# 최규환
# 김승현
# 지이수
# 최제우
# 이달형
# ==================================================
# 제목: 다운폴
# 평점: 9.00
# 장르:
# 전쟁
# 드라마
# 감독:
# 올리버 히르비겔
# 배우:
# 브루노 간츠
# 알렉산드라 마리아 라라
# 코리나 하르포히
# 울리히 마트데스
# 율리안느 콜러
# 헤이노 페르치
# 크리스찬 버켈
# ==================================================
# 제목: 더 파티
# 평점: 8.07
# 장르:
# 코미디
# 드라마
# 감독:
# 샐리 포터
# 배우:
# 크리스틴 스콧 토마스
# 패트리시아 클락슨
# 킬리언 머피
# 티모시 스폴
# 브루노 강쯔
# 체리 존스
# 에밀리 모티머
# ==================================================
# 제목: 미스 사이공: 25주년 특별 공연
# 평점: 9.18
# 장르:
# 공연실황
# 감독:
# 브렛 설리반
# 배우:
# 알리스태어 브래머
# 에바 노블자다
# 홍광호
# 존 존 브라이언스
# ==================================================
# 제목: 베를린 천사의 시
# 평점: 8.65
# 장르:
# 판타지
# 드라마
# 멜로/로맨스
# 감독:
# 빔 벤더스
# 배우:
# 브루노 간츠
# 솔베이그 도마르틴
# 오토 샌더
# ==================================================
# 제목: 비투스
# 평점: 8.94
# 장르:
# 드라마
# 감독:
# 프레디 M. 무러
# 배우:
# 브루노 강쯔
# 테오 게오르규
# ==================================================
# 제목: 영원과 하루
# 평점: 8.46
# 장르:
# 드라마
# 감독:
# 테오도로스 앙겔로플로스
# 배우:
# 브루노 간츠
# ==================================================

# %% [markdown]
# #### 조건에 따라 데이터 선택하기

# %%
import requests
from bs4 import BeautifulSoup
raw= requests.get("https://movie.naver.com/movie/running/current.nhn",
                  headers={'User-Agent': 'Morzilla/5.0'})
html = BeautifulSoup(raw.text,'html.parser')

movies = html.select("dl.lst_dsc")
for m in movies:
    title = m.select_one('dt.tit a')
    score = m.select_one('div.star_t1 span.num')
    genre = m.select("dl.info_txt1 dd:nth-of-type(1) a")
    director = m.select("dl.info_txt1 dd:nth-of-type(2) a")
    actor = m.select("dl.info_txt1 dd:nth-of-type(3) a")
    # genre_all이라는 변수에 전체 장르를 수집
    genre_all = m.select_one("dl.info_txt1 dd:nth-of-type(1) span.link_txt")

    # 평점이 8.5이상인 경우만 선택
    # continue는 조건이 참이면 현재 반복을 종료하고 다음 순서의 반복문이 실행되도록 합니다.
    if float(score.text) < 8.5:
        continue
    
    # 장르가 액션인 경우만 선택
    # 장르는 태그가 붙어있는 상태로 수집된 상태. 따라서 텍스트의 상태로 바꿔줘야 함
    if '액션' not in genre_all.text:
        continue

    print('제목:', title.text)
    print('평점:', score.text)
    print('장르:')
    for g in genre:
        print(g.text)
    print('감독:')
    for d in director:
        print(d.text)
    print('배우:')
    for a in actor:
        print(a.text)
    print('='*50)
# Out:
# 제목: 젠틀맨
# 평점: 8.51
# 장르:
# 범죄
# 액션
# 감독:
# 가이 리치
# 배우:
# 매튜 맥커너히
# 휴 그랜트
# 콜린 파렐
# 찰리 허냄
# 헨리 골딩
# 미셀 도커리
# ==================================================
# 제목: 포드 V 페라리
# 평점: 9.51
# 장르:
# 액션
# 드라마
# 감독:
# 제임스 맨골드
# 배우:
# 맷 데이먼
# 크리스찬 베일
# ==================================================
# 제목: 극장판 원피스 스탬피드
# 평점: 8.93
# 장르:
# 모험
# 액션
# 판타지
# 애니메이션
# 감독:
# 오츠카 타카시
# 배우:
# 타나카 마유미
# 나카이 카즈야
# 오카무라 아케미
# 야마구치 캇페이
# ==================================================
# 제목: 인셉션
# 평점: 9.23
# 장르:
# 액션
# 모험
# SF
# 스릴러
# 감독:
# 크리스토퍼 놀란
# 배우:
# 레오나르도 디카프리오
# 와타나베 켄
# 조셉 고든 레빗
# 마리옹 꼬띠아르
# 엘렌 페이지
# 톰 하디
# ==================================================
# 제목: 해리 포터와 아즈카반의 죄수
# 평점: 8.68
# 장르:
# 판타지
# 가족
# 모험
# 액션
# 감독:
# 알폰소 쿠아론
# 배우:
# 다니엘 래드클리프
# 엠마 왓슨
# 루퍼트 그린트
# ==================================================

# %% [markdown]
# ## IMDb 영화 데이터 수집하기

# %%
import requests
from bs4 import BeautifulSoup
raw= requests.get("https://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth",
                  headers={'User-Agent': 'Morzilla/5.0'})
html = BeautifulSoup(raw.text,'html.parser')

movies = html.select("td.overview-top")

for m in movies:
    title = m.select_one('h4 > a').text
    info = m.select('div.txt-block')
    # 1. 리스트 활용
    director = info[0].select('a')
    stars = info[1].select('a')
    print('='*50)
    print('제목: ', title)
    print('감독: ')
    for d in director:
        print(d.text)
    print('배우: ')
    for s in stars:
        print(s.text)
# Out:
# ==================================================
# 제목:   The Invisible Man (2020)
# 감독:
# Leigh Whannell
# 배우:
# Elisabeth Moss
# Oliver Jackson-Cohen
# Harriet Dyer
# Aldis Hodge
# ==================================================
# 제목:   Wendy (2020)
# 감독:
# Benh Zeitlin
# 배우:
# Yashua Mack
# Devin France
# Gage Naquin
# Gavin Naquin
# ==================================================
# 제목:   Ride (2018)
# 감독:
# Alex Ranarivelo
# 배우:
# Shane Graham
# Ludacris
# Sasha Alexander
# Blake Sheldon
# ==================================================
# 제목:   Burden (2018)
# 감독:
# Andrew Heckler
# 배우:
# Andrea Riseborough
# Garrett Hedlund
# Forest Whitaker
# Tom Wilkinson
# ==================================================
# 제목:   La Gomera (2019)
# 감독:
# Corneliu Porumboiu
# 배우:
# Vlad Ivanov
# Catrinel Marlon
# Rodica Lazar
# Agustí Villaronga
# ==================================================
# 제목:   Saint Frances (2019)
# 감독:
# Alex Thompson
# 배우:
# Kelly O'Sullivan
# Charin Alvarez
# Braden Crothers
# William Drain
# ==================================================
# 제목:   Hvítur, hvítur dagur (2019)
# 감독:
# Hlynur Palmason
# 배우:
# Ingvar Sigurdsson
# Ída Mekkín Hlynsdóttir
# Hilmir Snær Guðnason
# Sara Dögg Ásgeirsdóttir
# ==================================================
# 제목:   Lost in America (2018)
# 감독:
# Rotimi Rainwater
# 배우:
# Rosario Dawson
# Halle Berry
# Tiffany Haddish
# Jon Bon Jovi
# ==================================================
# 제목:   Sonic the Hedgehog (2020)
# 감독:
# Jeff Fowler
# 배우:
# Ben Schwartz
# James Marsden
# Jim Carrey
# Tika Sumpter
# ==================================================
# 제목:   The Call of the Wild (2020)
# 감독:
# Chris Sanders
# 배우:
# Harrison Ford
# Omar Sy
# Cara Gee
# Dan Stevens
# ==================================================
# 제목:   Birds of Prey: And the Fantabulous Emancipation of One Harley Quinn (2020)
# 감독:
# Cathy Yan
# 배우:
# Margot Robbie
# Rosie Perez
# Mary Elizabeth Winstead
# Jurnee Smollett-Bell
# ==================================================
# 제목:   Bad Boys for Life (2020)
# 감독:
# Adil El Arbi
# Bilall Fallah
# 배우:
# Will Smith
# Martin Lawrence
# Vanessa Hudgens
# Alexander Ludwig
# ==================================================
# 제목:   Brahms: The Boy II (2020)
# 감독:
# William Brent Bell
# 배우:
# Katie Holmes
# Owain Yeoman
# Christopher Convery
# Ralph Ineson
# ==================================================
# 제목:   Fantasy Island (2020)
# 감독:
# Jeff Wadlow
# 배우:
# Michael Peña
# Maggie Q
# Lucy Hale
# Austin Stowell
# ==================================================
# 제목:   1917 (2019)
# 감독:
# Sam Mendes
# 배우:
# Dean-Charles Chapman
# George MacKay
# Daniel Mays
# Colin Firth
# ==================================================
# 제목:   Gisaengchung (2019)
# 감독:
# Bong Joon Ho
# 배우:
# Kang-ho Song
# Sun-kyun Lee
# Yeo-jeong Jo
# Woo-sik Choi
# ==================================================
# 제목:   Jumanji: The Next Level (2019)
# 감독:
# Jake Kasdan
# 배우:
# Dwayne Johnson
# Jack Black
# Kevin Hart
# Karen Gillan
# ==================================================
# 제목:   The Photograph (2020)
# 감독:
# Stella Meghie
# 배우:
# LaKeith Stanfield
# Chelsea Peretti
# Issa Rae
# Chanté Adams

# %%
import requests
from bs4 import BeautifulSoup
raw= requests.get("https://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth",
                  headers={'User-Agent': 'Morzilla/5.0'})
html = BeautifulSoup(raw.text,'html.parser')

movies = html.select("td.overview-top")

for m in movies:
    title = m.select_one('h4 > a').text
    # 2. nth-of-type 활용
    director = m.select('> div:nth--of-type(3) a')
    stars = m.select('> div:nth--of-type(4) a')
    print('='*50)
    print('제목: ', title)
    print('감독: ')
    for d in director:
        print(d.text)
    print('배우: ')
    for s in stars:
        print(s.text)
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\User\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-5-4e457de4fa93>", line 12, in <module>
#     director = m.select('> div:nth--of-type(3) a')
#
#   File "C:\Users\User\Anaconda3\lib\site-packages\bs4\element.py", line 1334, in select
#     return soupsieve.select(selector, self, namespaces, limit, **kwargs)
#
#   File "C:\Users\User\Anaconda3\lib\site-packages\soupsieve\__init__.py", line 114, in select
#     return compile(select, namespaces, flags, **kwargs).select(tag, limit)
#
#   File "C:\Users\User\Anaconda3\lib\site-packages\soupsieve\__init__.py", line 63, in compile
#     return cp._cached_css_compile(pattern, namespaces, custom, flags)
#
#   File "C:\Users\User\Anaconda3\lib\site-packages\soupsieve\css_parser.py", line 205, in _cached_css_compile
#     CSSParser(pattern, custom=custom_selectors, flags=flags).process_selectors(),
#
#   File "C:\Users\User\Anaconda3\lib\site-packages\soupsieve\css_parser.py", line 1064, in process_selectors
#     return self.parse_selectors(self.selector_iter(self.pattern), index, flags)
#
#   File "C:\Users\User\Anaconda3\lib\site-packages\soupsieve\css_parser.py", line 959, in parse_selectors
#     sel, m, has_selector, selectors, relations, is_pseudo, index
#
#   File "C:\Users\User\Anaconda3\lib\site-packages\soupsieve\css_parser.py", line 785, in parse_combinator
#     index
#
#   File "<string>", line unknown
# SelectorSyntaxError: The combinator '>' at postion 0, must have a selector before it
#   line 1:
# > div:nth--of-type(3) a
# ^

# %%
import requests
from bs4 import BeautifulSoup
raw= requests.get("https://www.imdb.com/movies-in-theaters/?ref_=nv_mv_inth",
                  headers={'User-Agent': 'Morzilla/5.0'})
html = BeautifulSoup(raw.text,'html.parser')

movies = html.select("td.overview-top")

for m in movies:
    title = m.select_one('h4 > a').text
    info = m.select('div.txt-block')
    director = info[0].select('a')
    stars = info[1].select('a')
    
    genre_all = m.select_one("p.cert-runtime-genre")

    # 장르가 Action인 경우만 선택
    if 'Action' not in genre_all.text:
        continue
    
    print('='*50)
    print('제목: ', title)
    print('감독: ')
    for d in director:
        print(d.text)
    print('배우: ')
    for s in stars:
        print(s.text)
# Out:
# ==================================================
# 제목:   Ride (2018)
# 감독:
# Alex Ranarivelo
# 배우:
# Shane Graham
# Ludacris
# Sasha Alexander
# Blake Sheldon
# ==================================================
# 제목:   Sonic the Hedgehog (2020)
# 감독:
# Jeff Fowler
# 배우:
# Ben Schwartz
# James Marsden
# Jim Carrey
# Tika Sumpter
# ==================================================
# 제목:   Birds of Prey: And the Fantabulous Emancipation of One Harley Quinn (2020)
# 감독:
# Cathy Yan
# 배우:
# Margot Robbie
# Rosie Perez
# Mary Elizabeth Winstead
# Jurnee Smollett-Bell
# ==================================================
# 제목:   Bad Boys for Life (2020)
# 감독:
# Adil El Arbi
# Bilall Fallah
# 배우:
# Will Smith
# Martin Lawrence
# Vanessa Hudgens
# Alexander Ludwig
# ==================================================
# 제목:   Jumanji: The Next Level (2019)
# 감독:
# Jake Kasdan
# 배우:
# Dwayne Johnson
# Jack Black
# Kevin Hart
# Karen Gillan
